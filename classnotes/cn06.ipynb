# %% [markdown]
# # CS 1066 Classnotes (20260923)

# %% [markdown]
# ### As You Get Settled
#
# 1.  Start your CS1066 codespace. Go to `https://github.com/<your_username>/cs1066`, and either launch a new or restart the existing codespace for this repo.
#
# 2.  In this codespace, run `python3 grab1066.py m05a`. If you get an error, run `cd /workspaces/cs1066` in the terminal and then rerun the grab command.
#
# 3.  To get ready for the quiz, set your cellphone to silent, put your electronics away, and grab a pencil/pen.

# %% [markdown]
# ----
# ----
#
# ### Today's topics:
#
# 1.  Quiz 2
# 2.  Daily musings
# 3.  Failures while building our EDGAR app, which might help you while you build yours.
# 4.  A failure taxonomy and any additions you might have to offer.
# 5.  Revisiting process.

# %% [markdown]
# ----
# ----
#
# ### Today's Philosophical Musing
#
# **A suggested exercise:** Sometime in the near future, ask a diverse mix of people how they use AI. Listen intently, then cluster and label the responses. What was revealed?
#
# I recently did this exercise, and here's what I heard (already clustered and labeled):
#
# -   I use AI to be more efficient.
# -   I use AI to accomplish things not previously possible.
# -   I use AI to accelerate my journey of discovery.
# -   I use AI as a(nother) partner mind.

# %% [markdown]
# **Change.** Media likes to hype "revolutionary change" but the truth is that most change is gradual. You can miss it if you don't pay attention. Think of the metaphor of the boiling frog.
#
# > RECOMMENDED READING: "[How Claude Code Is Built](https://newsletter.pragmaticengineer.com/p/how-claude-code-is-built)" by Gergely Orosz (Sep. 23, 2025)
#
# -   The article describes a sit-down with "Boris Cherny (the engineer who came up with the original prototype, and the founding engineer of the project), Sid Bidasaria (engineer #2 of Claude Code, and creator of Claude Code subagents), and founding product manager Cat Wu."
#
# -   While the article talks in detail about how software engineering is changing, it could be a model for how AI might change other disciplines.

# %% [markdown]
# Notable quotes from the article:
#
# -   You can be more efficient: "Building and testing 5-10 prototype ideas in a day is possible with AI agents."
#
# -   "Claude Code is just a lightweight shell on top of the Claude model .... The Claude Code team tries to write as little business logic as possible." Boris is quoted as saying, "[T]he way we build [Claude Code] is we want people to feel the model as raw as possible. We have this belief the model can do much more than products today enable it to do."
#
# -   And for Spiderman fans, "with great power comes great responsibility." Boris again, "Claude Code runs batch commands locally, and reads and writes to the filesystem. There's no virtualization." The most complex part of Claude Code is the permissions system. Getting permissions right takes effort.

# %% [markdown]
# Which leads us to our next topic: Can we develop good mental models for **how AIs fail** and then protect ourselves against these failure modes?

# %% [markdown]
# ----
# ----
#
# ### My Failures Building the EDGAR App
#
# While you're building your own EDGAR app with AI help, let's talk about what I experienced first building it in January 2026 and then again in August 2026.
#
# **NOTE:** Why two dates? Our AI tools are constantly improving. You won't experience the exact same issues that I did, but you will almost certainly encounter similar ones. We'll look for general truths about AI failures.

# %% [markdown]
# ----
#
# **EXAMPLE #1:** Here's my prompt that had AI write a script that extracts Net Income from a data file like `amd_data.json`, which I pulled from EDGAR (and you've previously seen):
#
# > **PROMPT:** Limit your attention to the directory `m04`. Take a look at `amd_data.json`, notice its structure. Then write a script called `step2.py` building on our work in `step1.py` (import its function). Make a generic function, `extract_metric`, to extract a metric of our choosing, in our case, we’ll extract `NetIncomeLoss` from `amd_data.json` for annual reports (10-K, FY).  Handle duplicate entries per fiscal year by: (1) Filtering for periods spanning ~365 days (full year, not quarterly), then (2) Matching the period dates to the fiscal year (avoid historical restatements), (3) Selecting entries where the end date year matches the fiscal year. Finally, show fiscal year, value, and year-over-year growth.
#
# What do you notice about this prompt?

# %% [markdown]
# .
#
# ..
#
# ...
#
# .... PLEASE DON'T SCROLL DOWN UNTIL TOLD TO DO SO
#
# ...
#
# ..
#
# .

# %% [markdown]
# And here's an alternative:
#
# > **PROMPT:** In the directory `m05`, write a Python program to extract Net Income from the file `amd_data.json` and print the yearly values.
#
# NOTE: I've changed the directory so that I can run this prompt in today's working directory, i.e., `m05`.

# %% [markdown]
# **January 2026:** When prompted, AI confidently produced code, which is named `extract_net_income_gpt4o.py`. Let's run it, and you tell me what happened.

# %%
python3 extract_net_income_gpt4o.py
# Out:
#   Cell In[1], line 1
#     python3 extract_net_income_gpt4o.py
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Today:** You might argue that today's models are better than those in the past, and you'd be right. Let's try with the default model in our IDE:
#
# -   I'll delete `extract_net_income_gpt4o.py` to avoid biasing the results.
# -   I'll copy the prompt, which will probably create a program called `extract_net_income.py`.
# -   And I'll run it.

# %%
python3 extract_net_income.py

# %% [markdown]
# > What do you think?
#
# ... WRITE YOUR THOUGHTS HERE ...

# %% [markdown]
# ----
#
# **EXAMPLE #2:** Let's assume I moved on to extract AMD's revenue numbers from the JSON file. Here's a short prompt:
#
# > **PROMPT:** In the directory `m05`, write a python script to get AMD's revenue from the JSON file.

# %% [markdown]
# **January 2026:** AI created `get_amd_revenue_gpt4o.py` ("_gpt4o" extension added by me). Let's run it, and you tell me what happened.

# %%
python3 get_amd_revenue_gpt4o.py

# %% [markdown]
# **Today:** Will today's models negate the need for this specificity? Live demo time!
#
# -   I'll delete `get_amd_revenue_gpt4o.py` to avoid biasing the results.
# -   I'll copy the prompt, which will probably create a program called `get_amd_revenue.py`.
# -   And I'll run it.

# %%
python3 get_amd_revenue.py

# %% [markdown]
# ----
#
# ### Takeaways
#
# Process comments:
#
# 1.  It's okay to start with a short prompt.
# 2.  But don't trust the result without rigorous verification.
# 3.  Use what you learn from the verification process to determine what information you should have included in your prompt.
# 4.  Rewrite your prompt and iterate (return to step 2), until the generated program _and_ its output passes your rigorous verification process.
#
# Comments about prompting:
#
# -   Prompting is never a one-and-done process, even if you spend a lot of time in design.
# -   Prompting is also not only about how you structure your prompt to get a good AI response.
# -   Prompting is part of an iterative process.

# %% [markdown]
# ----
# ----
#
# ### A Failure Taxonomy
#
# Here are five commonly encountered failure modes when **an initial prompt doesn't work**:
#
# 1.  Hallucinations and fabricated data
#
#     -  E.g., AI chooses a similarly named key or generates placeholder data.
#     -  Live demo? In the directory with `amd_data.json`, prompt AI to "write a python script that gets and compares Apple and AMD revenue data."
#     -  Mitigation: Check the code and cross-reference AI outputs against known sources.

# %% [markdown]
# 2.  Silent failures
#
#     -  The code runs without errors but produces incorrect results. AI gives no assessment of its confidence in the generated program.
#     -  Live demo? We saw an example of this with `extract_net_income.py`.
#     -  Mitigation: Test with data where you already know the answer.

# %% [markdown]
# 3.  Misinterpretation of intent
#
#     -  AI understands your words but not your meaning. English is ambiguous. Words like "latest," "current," "recent," and "new" have different meanings in different contexts.
#     -  Example: Consider the directive, "Get the latest financial data." It could mean: the most recently filed document, or data from the last calendar year, or the document with the newest "last modified" timestamp.
#     -  Mitigation: Ask the AI how it interpreted potentially ambiguous terms and review the AI's code to verify this response.

# %% [markdown]
# 4.  Hidden assumptions
#
#     -  AI makes important decisions without telling you.  Or it buries these decisions in its many paragraphs of output that you didn’t read!
#     -  Example: When you ask for "revenue," AI might assume you want annual revenue (not quarterly), in USD (not other currencies), from operating activities (not total revenue). Only you can determine whether an assumption is reasonable for your use case.
#     -  Mitigation: Read the comments and skim through the AI-generated code. Highlight some code and ask AI to explain its assumptions.

# %% [markdown]
# 5.  Brittle code
#
#     -  The AI-generated code runs and produces correct output for a common example (e.g., the one you included in the prompt), but it breaks on edge cases. AI often optimizes for the example you give it, not for general robustness.
#     -  Example: Code that extracts Net Income from AMD's data might fail completely when you try it on a different company because that company uses a different accounting standard, or has a different fiscal year end, or has on file very few years of data, or has years without data.
#     -  Mitigation: Test with multiple inputs, including edge cases. Try companies of different sizes, different industries, and different filing histories. We'll talk testing next!

# %% [markdown]
# ----
#
# ### Will Crowd Sourcing Produce More?
#
# Do you have other examples to add to this taxonomy? Take a moment to think and then summarize your experiences below.
#
# ... WRITE YOUR THOUGHTS HERE ...

# %% [markdown]
# ----
# ----
#
# ### Revisiting Process
#
# This is where we left the problem-solving process in `cn02`:
#
# 1.  Identify a task you want automated
# 2.  Set the requirements for the tool that'll automate the task
# 3.  While the tool is incomplete:
#
#     3a.  Pick a(nother) small part and give its requirements to the AI
#
#     3b.  Check what the AI built
#
# 4.  Use the tool and focus on the interesting work
#
# It focuses on decomposition and assumes what the AI builds works, which we now know is often true with straightforward problems (e.g., a Mad Libs app) but not with more complex ones.
#
# Step 3b becomes:
#
# -   Recognize when the AI has failed (not always obvious)
# -   Diagnose which failure mode occurred
# -   Revise your prompt to fix it
#
# This adds a loop within the loop driven by decomposition. It is the more difficult workflow of problem solving with AI.
#
# In section, we'll start on recognition/diagnosing failures with some testing strategies. Soon, we'll introduce a new business problem so you can practice this cycle of identifying a problem, diagnosing it, and eventually overcoming it.

# %% [markdown]
# ----
# ----
#
# ### Commit Your Notes and Edits
#
# Don't forget to review, commit, and push your edits so that you've updated your GitHub repo with today's work.
#
# *   `git status` to review what's new and what's been edited.
# *   `git add <list_of_files>` to indicate what you want committed.
# *   `git commit -m "<your_commit_message>"` to commit the changes to the codespace's filesystem.
# *   `git push` to push those committed changes to your GitHub repo.
# *   `git status` to verify that you haven't forgotten anything.

# %% [markdown]
# Version 20260827
